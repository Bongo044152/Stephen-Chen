# %% [markdown]
# # **資料庫可視化區域**
#
# sqlite3 搭配 pandas 可以讀取來自資料庫中的資料。
#
# > **註記! 由於我對於 sqlite 不是很熟悉，因此 sqlite 的程式碼都是 GPT 完成的，但是能看懂一點 SQL 語法**

# %% [markdown]
# - **pandas docs : https://pandas.pydata.org/**
# - **sqlite3 : 乾我屁事!**

# %%
import sqlite3      # 輕量級的 sql 資料庫
import pandas as pd # python 版的 excel

# %%
def fetch_professor_data(professor_name: str):
    # 連接到 SQLite 資料庫
    conn = sqlite3.connect('professor_data.db')

    # 查詢教授資料
    professor_query = '''
        SELECT * FROM professor_data WHERE name = ?
    '''
    professor_df = pd.read_sql(professor_query, conn, params=(professor_name,))
    professor_df.set_index('id', inplace=True)
    
    if professor_df.empty:
        print(f"未找到名為 {professor_name} 的教授資料！")
        return

    # 顯示教授基本資料
    print("\n教授資料:")
    display(professor_df)

    # 查詢該教授的經歷
    experience_query = '''
        SELECT * FROM experience WHERE professor_id = ?
    '''
    professor_id = int(professor_df.index[0])  # 取得教授 ID
    experience_df = pd.read_sql(experience_query, conn, params=(professor_id,))
    experience_df.set_index('id', inplace=True)

    # 顯示教授經歷資料
    print("\n教授經歷資料:")
    if not experience_df.empty:
        display(experience_df)
    else:
        print("這個教授沒有經歷資料...")

    # 查詢該教授的研究領域
    research_field_query = '''
        SELECT * FROM research_field WHERE professor_id = ?
    '''
    research_field_df = pd.read_sql(research_field_query, conn, params=(professor_id,))
    research_field_df.set_index('id', inplace=True)

    # 顯示教授研究領域資料
    print("\n教授研究領域資料:")
    if not research_field_df.empty:
        display(research_field_df)
    else:
        print("這個教授沒有研究領域...")

    # 關閉資料庫連接
    conn.close()

# %%
def browse_all_data():
    # 連接到 SQLite 資料庫
    conn = sqlite3.connect('professor_data.db')

    # 查詢所有教授資料
    professor_df = pd.read_sql('SELECT * FROM professor_data', conn)
    professor_df.set_index('id', inplace=True)
    print("\n所有教授資料:")
    display(professor_df)

    # 查詢所有經歷資料
    experience_df = pd.read_sql('SELECT * FROM experience', conn)
    experience_df.set_index('id', inplace=True)
    print("\n所有經歷資料:")
    display(experience_df)

    # 查詢所有研究領域資料
    research_field_df = pd.read_sql('SELECT * FROM research_field', conn)
    research_field_df.set_index('id', inplace=True)
    print("\n所有研究領域資料:")
    display(research_field_df)

    conn.close()

# %% [markdown]
# ### **清除教授的資料**
#
# > **慎用! 資料刪除後無法恢復!!**

# %%
def clear_database():
    # 連接到資料庫
    conn = sqlite3.connect('professor_data.db')
    cursor = conn.cursor()

    # 刪除所有資料表
    cursor.execute('DROP TABLE IF EXISTS professor_data')
    cursor.execute('DROP TABLE IF EXISTS experience')
    cursor.execute('DROP TABLE IF EXISTS research_field')

    # 提交並關閉連接
    conn.commit()
    conn.close()
    print("資料庫中的所有資料表已被清除!")

# %% [markdown]
# ### **測試**

# %%
fetch_professor_data('陳良弼(Arbee L.P. Chen)')
# Out:
# 教授資料:
#                     name title      education              email office  \
# id
# 4   陳良弼(Arbee L.P. Chen)  講座教授  美國南加州大學資訊工程博士  arbee@asia.edu.tw   I513
#
#                    office_hour
# id
# 4   時程表: https://ppt.cc/fdl8ox
# 教授經歷資料:
#     professor_id        experience
# id
# 19             4          國立清華大學教授
# 20             4  國立政治大學講座教授兼理學院院長
# 教授研究領域資料:
#     professor_id research_field
# id
# 14             4         巨量資料分析
# 15             4        資料庫偏愛查詢
# 16             4         行動資訊系統

# %%
fetch_professor_data('Tadao Murata')
# Out:
# 教授資料:
#             name title              education email office office_hour
# id
# 32  Tadao Murata  榮譽教授  學伊利諾大學厄巴納-香檳分校 電機工程博士  None   None        None
# 教授經歷資料:
# 這個教授沒有經歷資料...
#
# 教授研究領域資料:
#      professor_id                                     research_field
# id
# 138            32  Applications of Petri nets to problems related...

# %%
browse_all_data()
# Out:
# 所有教授資料:
#                        name        title               education  \
# id
# 1     張文鐘 (Wen-Thong Chang)     特聘教授兼系主任         卡內基美隆大學 電機電腦 博士
# 2   蔡進發 （Jeffrey J.P. Tsai）  講座教授、亞洲大學校長       美國西北大學電機工程與電腦科學博士
# 3         許聞廉(Wen-Lian Hsu)         講座教授           美國康乃爾大學作業研究博士
# 4      陳良弼(Arbee L.P. Chen)         講座教授           美國南加州大學資訊工程博士
# 5     黃明祥(Min-Shiang Hwang)         講座教授            國立交通大學資訊科學博士
# 6      許慶賢(Ching-Hsien Hsu)         講座教授              逢甲大學資訊工程博士
# 7          李文熙(Wen-Hsi Lee)         講座教授           國立交通大學電子研究所博士
# 8       陳錫明(Shyi-Ming Chen)         講座教授            國立台灣大學電機工程博士
# 9       洪西進(Shi-Jinn Horng)         講座教授           國立清華大學 資訊科學博士
# 10         詹景裕(Gene-Eu Jan)         講座教授             馬麗蘭大學電機工程博士
# 11      蔡秀芬(Shiow-Fon Tsay)         講座教授              國立清華大學物理博士
# 12     蕭進松(Chin-Sung Hsiao)           教授              清華大學 電機 博士
# 13    陳興忠(Hsing-Chung Chen)         特聘教授           國立中正大學 電機工程博士
# 14      Brij Bhooshan Gupta         特聘教授       印度理工學院羅克 計算機科學 博士
# 15       施能義(Neng-Yih Shih)           教授     成功大學航空太空工程學系(控制組)博士
# 16       林俊淵(Chun-Yuan Lin)           教授              逢甲大學資訊工程博士
# 17        蔡志仁(Zhi-Ren Tsai)           教授                長庚大學電機博士
# 18       陳兆南(Chao-Nan Chen)          副教授          長庚大學電子工程研究所 博士
# 19        陳瑞奇(Jui-Chi Chen)          副教授            國立中興大學資訊科學博士
# 20      朱學亭(Hsueh-Ting Chu)          副教授            國立清華大學資訊工程博士
# 21       王經篤(Jing-Doo Wang)          副教授            國立中正大學資訊工程博士
# 22       葉榮輝(Rong-Hwei Yeh)          副教授              中央大學 電機 博士
# 23        柯賢儒 (Hsien-Ju Ko)          副教授             大同大學 電機所 博士
# 24        蔡至偉(Jr Wei, Tsai)          副教授       維吉尼亞理工學院暨州立大學物理博士
# 25        楊偉儒 (Wei-Zu Yang)         助理教授            國立交通大學資訊工程博士
# 26           THI-VAN NGUYEN         助理教授        國立台灣科技大學資訊工程學系博士
# 27            DINH-TRUNG VU         助理教授        國立台灣科技大學資訊工程學系博士
# 28         涂崇一(Chung-Yi Tu)         助理教授   國立中興大學 大數據產學研發博士學程 博士
# 29          吳函諺(Han-Yan Wu)         助理教授         國立交通大學資訊科學與工程博士
# 30  PANDI DIVYA PORKAIPANDI         助理教授          國立成功大學 電機工程 博士
# 31         關國裕(Kuo-Yu Kuan)           講師           國立成功大學電機工程博士班
# 32             Tadao Murata         榮譽教授   學伊利諾大學厄巴納-香檳分校 電機工程博士
# 33        曾憲章Zeng Xianzhang       榮譽講座教授  美國加州大學洛杉磯分校(UCLA)計算機博士
# 34       李錦輝 (Chin-Hui Lee)       榮譽講座教授                    None
# 35                      黃光彩       榮譽講座教授      美國麻省理工學院電機工程及電腦系博士
# 36  林一平 (Jason Yi-Bing Lin)       兼任講座教授           美國華盛頓大學資訊工程博士
# 37      張嘉淵 (Zhang Jiayuan)       兼任講座教授                    None
# 38            許健(Gene Sheu)       兼任講座教授           愛荷華大學實驗固態物理博士
# 39      梁文隆(Wen-Lung Liang)       兼任講座教授                高雄工專 機械科
# 40      林詠章 (Lin Yongzhang)         兼任教授                    None
# 41         李正吉 (Li Zhengji)         兼任教授                    None
# 42       徐中行 (Xu Zhongxing)         兼任教授        美國 羅格斯大學 計算機科學博士
# 43    曹世昌(Shyh-Chang Tsaur)         兼任教授         美國卡内基美隆大學電子工程博士
# 44      陳榮燊 (Chen Rongshen)        兼任副教授                    None
# 45      張峯銘(Chang Fengming)        兼任副教授        國立成功大學工業與資訊管理所博士
# 46        高興全(Gao Xingquan)       兼任助理教授       亞洲大學\t數位媒體設計學系 碩士
# 47           陳義吉(Chen Yiji)       兼任助理教授        中興大學\t機械工程學系\t博士
# 48        廖益聖(Liao Yisheng)       兼任助理教授             亞洲大學 資工系 博士
# 49         劉育寰 (Liu Yuhuan)       合聘助理教授                    None
# 50     黃麒昌(HUANG,CHI-CHANG)       兼任助理教授                    None
# 51     周存貹(CHOU,TSUN-SHENG)       兼任助理教授                    None
# 52             吳怡德(WU,I-TE)       兼任助理教授                    None
# 53     温在昇(Wen, Chai-Sheng)       兼任助理教授       國立臺灣海洋大學 電機工程學系博士
#
#                       email  \
# id
# 1       wtchang@asia.edu.tw
# 2     president@asia.edu.tw
# 3        wenhsu@asia.edu.tw
# 4         arbee@asia.edu.tw
# 5       mshwang@asia.edu.tw
# 6     robertchh@asia.edu.tw
# 7         wslee@asia.edu.tw
# 8        smchen@asia.edu.tw
# 9       horngsj@asia.edu.tw
# 10    geneeujan@asia.edu.tw
# 11  tsaysf.asia@asia.edu.tw
# 12      cshsiao@asia.edu.tw
# 13     cdma2000@asia.edu.tw
# 14      bbgupta@asia.edu.tw
# 15         shih@asia.edu.tw
# 16       cyulin@asia.edu.tw
# 17          ren@asia.edu.tw
# 18       chencn@asia.edu.tw
# 19        rikki@asia.edu.tw
# 20        htchu@asia.edu.tw
# 21       jdwang@asia.edu.tw
# 22        rhyeh@asia.edu.tw
# 23         hjko@asia.edu.tw
# 24       jamiet@asia.edu.tw
# 25       wzyang@asia.edu.tw
# 26        vannt@asia.edu.tw
# 27       tonyvu@asia.edu.tw
# 28    tu1chung1@asia.edu.tw
# 29     hanyanwu@asia.edu.tw
# 30    divya1671@asia.edu.tw
# 31          kky@asia.edu.tw
# 32                     None
# 33                     None
# 34                     None
# 35                     None
# 36                     None
# 37                     None
# 38                     None
# 39                     None
# 40                     None
# 41                     None
# 42                     None
# 43                     None
# 44                     None
# 45                     None
# 46                     None
# 47                     None
# 48                     None
# 49                     None
# 50                     None
# 51                     None
# 52                     None
# 53                     None
#
#                                                office  \
# id
# 1   亞洲大學資訊工程學系: 特聘教授且兼任系主任亞洲大學光電與通訊學系: 特聘教授且兼任系主任亞...
# 2                                                None
# 3                                                None
# 4                                                I513
# 5                                                I420
# 6                                                H602
# 7                                                A506
# 8                                                I612
# 9                                                I419
# 10                                               I609
# 11                                               A507
# 12                                       健康大樓六樓 H60AR
# 13                                               8015
# 14                                               I417
# 15                                        I624 / L505
# 16                                               I623
# 17                                               I521
# 18                                               8019
# 19                                               HB13
# 20                                               I511
# 21                                               I517
# 22                                     資訊大樓地下一樓 HB16R
# 23                                     資訊大樓地下一樓 HB42R
# 24                                               8014
# 25                                               HB33
# 26                                               8034
# 27                                               8032
# 28                                               8017
# 29                                               HB46
# 30                                               8029
# 31                                               HB65
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
#
#                    office_hour
# id
# 1   時程表: https://ppt.cc/fSC96x
# 2                         None
# 3   時程表: https://ppt.cc/frFkqx
# 4   時程表: https://ppt.cc/fdl8ox
# 5   時程表: https://ppt.cc/fCjspx
# 6   時程表: https://ppt.cc/fSYLTx
# 7   時程表: https://ppt.cc/f7m9Cx
# 8   時程表: https://ppt.cc/fcTZBx
# 9   時程表: https://ppt.cc/fDT21x
# 10  時程表: https://ppt.cc/fVBFyx
# 11  時程表: https://ppt.cc/f70Mrx
# 12  時程表: https://ppt.cc/fF945x
# 13  時程表: https://ppt.cc/fcWVnx
# 14  時程表: https://ppt.cc/fLNXgx
# 15  時程表: https://ppt.cc/fo4fRx
# 16  時程表: https://ppt.cc/fTeAVx
# 17  時程表: https://ppt.cc/fv4c1x
# 18  時程表: https://ppt.cc/flQRsx
# 19  時程表: https://ppt.cc/fb7oJx
# 20  時程表: https://ppt.cc/fn4Jcx
# 21  時程表: https://ppt.cc/f28tpx
# 22  時程表: https://ppt.cc/fDpGjx
# 23  時程表: https://ppt.cc/fuFlhx
# 24  時程表: https://ppt.cc/f4E8ox
# 25  時程表: https://ppt.cc/fKxz3x
# 26  時程表: https://ppt.cc/fs8Utx
# 27  時程表: https://ppt.cc/fx6iWx
# 28  時程表: https://ppt.cc/fsxs8x
# 29  時程表: https://ppt.cc/fdb6cx
# 30  時程表: https://ppt.cc/f0AQKx
# 31  時程表: https://ppt.cc/fZokgx
# 32                        None
# 33                        None
# 34                        None
# 35                        None
# 36                        None
# 37                        None
# 38                        None
# 39                        None
# 40                        None
# 41                        None
# 42                        None
# 43                        None
# 44                        None
# 45                        None
# 46                        None
# 47                        None
# 48                        None
# 49                        None
# 50                        None
# 51                        None
# 52                        None
# 53                        None
# 所有經歷資料:
#      professor_id                  experience
# id
# 1               2                    亞洲大學創校校長
# 2               2                   資訊工業策進會顧問
# 3               2              美國國防部先進研究計畫處顧問
# 4               2                  美國杜蘭大學合聘教授
# 5               2            美國德州大學奧斯丁分校資深研究員
# ..            ...                         ...
# 204            53           捷創科技 (Jtron) 副總經理
# 205            53  安捷倫科技 (Agilent) 亞洲區應用工程部協理
# 206            53       惠普科技 (HP) 半導體測試群應用工程師
# 207            53   宏碁電腦 (Acer) 伺服器事業處硬體研發工程師
# 208            53
#
# [208 rows x 2 columns]
# 所有研究領域資料:
#      professor_id research_field
# id
# 1               1          物連網系統
# 2               1           視訊串流
# 3               1           通訊系統
# 4               1           影像處理
# 5               2           人工智能
# ..            ...            ...
# 210            52           永續管理
# 211            53          半導體產業
# 212            53          半導體測試
# 213            53           訊號處理
# 214            53           水下聲學
#
# [214 rows x 2 columns]
